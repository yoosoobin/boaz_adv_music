# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
song = pd.read_json('/content/drive/Shareddrives/BOAZ_Adv/melon_data/song_meta.json')
song.head()
# Out:
#   song_gn_dtl_gnr_basket  issue_date  ... artist_name_basket  id
# 0               [GN0901]    20140512  ...  [Various Artists]   0
# 1       [GN1601, GN1606]    20080421  ...   [Murray Perahia]   1
# 2               [GN0901]    20180518  ...    [Peter Gabriel]   2
# 3       [GN1102, GN1101]    20151016  ...           [Matoma]   3
# 4       [GN1802, GN1801]    20110824  ...         [Jude Law]   4
#
# [5 rows x 9 columns]

# %%
song.rename(columns={"song_gn_dtl_gnr_basket":"곡 세부 장르 리스트", "issue_date":"발매일", "album_name": "앨범 명", "album_id":"앨범 ID", "artist_id_basket":"아티스트 ID 리스트", "song_name":"곡 제목", "song_gn_gnr_basket":"곡 장르 리스트", "artist_name_basket":"아티스트 리스트","id":"곡 ID"},inplace= True )
song.head()
# Out:
#         곡 세부 장르 리스트       발매일  ...           아티스트 리스트  곡 ID
# 0          [GN0901]  20140512  ...  [Various Artists]     0
# 1  [GN1601, GN1606]  20080421  ...   [Murray Perahia]     1
# 2          [GN0901]  20180518  ...    [Peter Gabriel]     2
# 3  [GN1102, GN1101]  20151016  ...           [Matoma]     3
# 4  [GN1802, GN1801]  20110824  ...         [Jude Law]     4
#
# [5 rows x 9 columns]

# %%
import re
 
def cleanText(readData):
 
    #텍스트에 포함되어 있는 특수 문자 제거
 
    text = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', '', readData)
 
    return text

# %%
gr = song['곡 장르 리스트']
sub = []
for n,i in enumerate(gr):
  a = cleanText(str(i))
  sub.append(a)

sub
# Out:
# ['GN0900',
#  'GN1600',
#  'GN0900',
#  'GN1100',
#  'GN1800',
#  'GN1700',
#  'GN1600',
#  'GN1600',
#  'GN0300',
#  'GN0100',
#  'GN1200',
#  'GN1300',
#  'GN1700',
#  'GN1700',
#  'GN2700 GN1100',
#  'GN1600',
#  'GN0900',
#  'GN2500 GN0200',
#  'GN2800',
#  'GN0500 GN0800',
#  'GN1600',
#  '',
#  'GN0900',
#  'GN1600',
#  'GN1100',
#  'GN0300',
#  'GN0900',
#  'GN1900',
#  'GN0900',
#  'GN1500',
#  'GN2500 GN1500 GN0200',
#  'GN1800',
#  'GN1500',
#  'GN2600',
#  'GN1100',
#  'GN0500 GN0800',
#  'GN1500',
#  'GN1700',
#  'GN1700',
#  'GN1300',
#  'GN1000',
#  'GN1700',
#  'GN1000',
#  'GN1400',
#  'GN1000',
#  'GN2000',
#  'GN1000',
#  'GN0500 GN0300',
#  'GN0800',
#  'GN0100',
#  'GN1000',
#  'GN2800',
#  'GN1300',
#  'GN2100',
#  'GN0100',
#  'GN1100',
#  'GN0900 GN1000',
#  'GN1300',
#  'GN0200',
#  'GN2200',
#  'GN0100',
#  'GN2000',
#  'GN0100',
#  'GN1800',
#  'GN1500',
#  'GN1600',
#  'GN1800',
#  'GN2500 GN0100',
#  'GN1800',
#  'GN1800',
#  'GN0100',
#  'GN1300',
#  'GN1200',
#  'GN1700',
#  'GN1100',
#  'GN1000',
#  'GN1300',
#  'GN2100',
#  'GN1200',
#  'GN1500',
#  'GN1000',
#  'GN0500 GN0600',
#  'GN1900',
#  'GN2700 GN1100',
#  'GN1600',
#  'GN0600',
#  'GN1800',
#  'GN1100',
#  'GN0900 GN1000',
#  'GN1000',
#  'GN1100',
#  'GN1100',
#  'GN1500 GN0100',
#  'GN1300',
#  'GN1600',
#  'GN1000',
#  'GN0800',
#  'GN1800',
#  'GN0900',
#  'GN1600',
#  'GN0900',
#  'GN0900 GN1000',
#  'GN1300',
#  'GN1700',
#  'GN1100',
#  'GN1800',
#  'GN0900',
#  'GN1000',
#  'GN0900',
#  'GN0900',
#  'GN1400',
#  'GN0100',
#  'GN2100',
#  'GN1700',
#  'GN1200',
#  'GN1800',
#  'GN1600',
#  'GN1100',
#  'GN1200',
#  'GN1100',
#  'GN1500 GN0100',
#  'GN0900',
#  'GN1700',
#  'GN1000',
#  'GN1600',
#  'GN1100',
#  'GN0300',
#  'GN0100',
#  'GN0300',
#  'GN0900',
#  'GN2200',
#  'GN0300',
#  'GN1200',
#  'GN0700',
#  'GN1600',
#  'GN1500 GN0100',
#  'GN2100',
#  'GN1100',
#  'GN1000',
#  'GN0500 GN0300',
#  'GN0900',
#  'GN1100',
#  'GN1200',
#  'GN0600',
#  'GN1000',
#  'GN1700',
#  'GN1500',
#  'GN1000',
#  'GN0500 GN0600',
#  'GN0100',
#  'GN1300',
#  'GN1100',
#  'GN1500',
#  'GN1100',
#  'GN1500 GN2200',
#  'GN0900',
#  'GN1600',
#  'GN0700',
#  'GN1800',
#  'GN1200',
#  'GN0900 GN1000',
#  'GN2200',
#  'GN1700',
#  'GN1700',
#  'GN1000',
#  'GN2000',
#  'GN1000',
#  'GN1500',
#  'GN1800',
#  'GN1000',
#  'GN1600',
#  'GN1100',
#  'GN0100',
#  'GN1100',
#  'GN2700 GN1100',
#  'GN1100',
#  'GN1400',
#  'GN2100',
#  'GN0600',
#  'GN1700',
#  'GN1300',
#  'GN0100',
#  'GN1200',
#  'GN1700',
#  'GN1800',
#  'GN1700',
#  'GN1600',
#  'GN0400',
#  'GN0900',
#  'GN1500 GN2900',
#  'GN1000',
#  'GN0400',
#  'GN1800',
#  'GN1800',
#  'GN1500',
#  'GN0200',
#  'GN1600',
#  'GN1200',
#  'GN0900',
#  'GN0800',
#  'GN0500 GN0400',
#  'GN1200',
#  'GN2000',
#  'GN1400',
#  'GN1000',
#  'GN0100',
#  'GN1200',
#  'GN1200',
#  'GN1600',
#  'GN0900',
#  'GN0100',
#  'GN0900',
#  'GN1000',
#  'GN0900 GN1000',
#  'GN1100',
#  'GN1700',
#  'GN1500',
#  'GN1100',
#  'GN0500 GN2600',
#  'GN1100',
#  'GN0600 GN1500',
#  'GN1000',
#  'GN0900',
#  'GN1200',
#  'GN0100',
#  'GN1400',
#  'GN1600',
#  'GN1800',
#  'GN1500',
#  'GN0500 GN0800',
#  'GN1000',
#  'GN1000',
#  'GN0900',
#  'GN2600',
#  'GN0500 GN0600',
#  'GN2500 GN0200',
#  'GN1900',
#  'GN1900',
#  'GN1300',
#  'GN0200',
#  'GN1600',
#  'GN1000',
#  'GN0300',
#  'GN1000',
#  'GN2700 GN1100',
#  'GN1300',
#  'GN0600',
#  'GN1100',
#  'GN1800',
#  'GN1200',
#  'GN0100',
#  'GN2100',
#  'GN1500 GN0300',
#  'GN0900',
#  'GN0500 GN0800',
#  'GN0900',
#  'GN2700',
#  'GN1300',
#  'GN2100',
#  'GN2000',
#  'GN0700',
#  'GN0600',
#  'GN9000',
#  'GN2100',
#  'GN0900',
#  'GN1800',
#  'GN2500 GN0100',
#  'GN1900',
#  'GN1100',
#  'GN0900',
#  'GN1200',
#  'GN0500 GN0600',
#  'GN2000',
#  'GN1500 GN0300',
#  'GN1200',
#  'GN2700 GN1100',
#  'GN2000',
#  'GN0900',
#  'GN2000',
#  'GN1600',
#  'GN1900',
#  'GN1900',
#  'GN1400',
#  'GN1300',
#  'GN1000',
#  'GN1600',
#  'GN1000',
#  'GN1100',
#  'GN1600',
#  'GN0400',
#  'GN1500 GN2200',
#  'GN1400',
#  'GN2100',
#  'GN0700',
#  'GN0300',
#  'GN1800',
#  'GN0400',
#  'GN2000',
#  'GN0400',
#  'GN0900',
#  'GN1600',
#  'GN1200',
#  'GN1900',
#  'GN1300',
#  'GN0300',
#  'GN0100',
#  'GN1000',
#  'GN0900',
#  'GN1300',
#  'GN0500 GN0400',
#  'GN1600',
#  'GN0400',
#  'GN1300',
#  'GN1100',
#  'GN2200',
#  'GN1700',
#  'GN1600',
#  'GN0100',
#  'GN1300',
#  'GN0500 GN0300',
#  'GN1700',
#  'GN1600',
#  'GN1300',
#  'GN0200',
#  'GN0700',
#  'GN0600',
#  'GN1000',
#  'GN1500',
#  'GN1100',
#  'GN2200',
#  'GN0100',
#  'GN1600',
#  'GN0300',
#  'GN1000',
#  'GN1500',
#  'GN1900',
#  'GN1600',
#  'GN1800',
#  'GN0200',
#  'GN0500 GN0800',
#  'GN0300',
#  'GN0200',
#  'GN1300',
#  'GN0600',
#  'GN1300',
#  'GN1700',
#  'GN2700',
#  'GN0400',
#  'GN1800',
#  'GN0500 GN0100',
#  'GN0600',
#  'GN1000',
#  'GN0100',
#  'GN1500',
#  'GN1700',
#  'GN0600',
#  'GN0100',
#  'GN0500 GN0600',
#  'GN1200',
#  'GN2100',
#  'GN1600',
#  'GN2200',
#  'GN1600',
#  'GN0500 GN0800',
#  'GN1100',
#  'GN1800',
#  'GN1200',
#  'GN2000',
#  'GN2700 GN1100',
#  'GN1800',
#  'GN1000',
#  'GN0600',
#  'GN1800',
#  'GN1600',
#  'GN1800',
#  'GN1800',
#  'GN2000',
#  'GN1100',
#  'GN1600',
#  'GN1100',
#  'GN1500',
#  'GN1200',
#  'GN1600',
#  'GN1000',
#  'GN1800',
#  'GN0200',
#  'GN2600',
#  'GN1700',
#  'GN1900',
#  'GN2200',
#  'GN1100',
#  'GN1100',
#  'GN1000',
#  'GN1000',
#  'GN2200',
#  'GN1600',
#  'GN1600',
#  'GN2700 GN1100',
#  'GN0900',
#  '',
#  'GN1300',
#  'GN0900',
#  'GN1000',
#  'GN1000',
#  'GN1700',
#  'GN1100',
#  'GN1200',
#  'GN2200',
#  'GN1100',
#  'GN1300',
#  'GN0900',
#  'GN1100',
#  'GN1300',
#  'GN1500 GN0200',
#  'GN0300',
#  'GN1100',
#  'GN0900',
#  'GN1200',
#  'GN1700',
#  'GN0900',
#  'GN0900',
#  'GN1500',
#  'GN1800',
#  'GN1700',
#  'GN1300',
#  'GN1600',
#  'GN2500 GN0100',
#  'GN1500',
#  'GN2300',
#  'GN0900',
#  'GN0900',
#  'GN1800',
#  'GN1800',
#  'GN1600',
#  'GN1600',
#  'GN0100',
#  'GN1900',
#  'GN0200',
#  'GN0600',
#  'GN1100',
#  'GN0600',
#  'GN2100',
#  'GN1600',
#  'GN0700',
#  'GN0700',
#  'GN1200',
#  'GN0500 GN0300',
#  'GN2500 GN0200',
#  'GN1200',
#  'GN0900',
#  'GN1100',
#  'GN1500 GN0100',
#  'GN1100',
#  'GN1700',
#  'GN1100',
#  'GN2500 GN1500 GN0200',
#  'GN2200',
#  'GN1800',
#  'GN1200',
#  'GN1800',
#  'GN0900',
#  'GN1200',
#  'GN1300',
#  'GN1500 GN0100',
#  'GN1100',
#  'GN1300',
#  'GN0900 GN1000',
#  'GN1500',
#  'GN1500',
#  'GN1600',
#  'GN1300',
#  'GN1000',
#  'GN2200',
#  'GN1300',
#  'GN0300',
#  'GN1600',
#  'GN1000',
#  'GN1000',
#  'GN1400',
#  'GN0400',
#  'GN1800',
#  'GN1500',
#  'GN1900',
#  'GN1500',
#  'GN1200',
#  'GN1300',
#  'GN0900',
#  'GN1800',
#  'GN0600',
#  'GN0900',
#  'GN1500',
#  'GN1300',
#  'GN1900',
#  'GN2500 GN0100',
#  'GN1100',
#  'GN1000',
#  'GN0100',
#  'GN1600',
#  'GN1600',
#  'GN1200',
#  'GN1200',
#  'GN0900',
#  'GN1800',
#  'GN1100',
#  'GN1800',
#  'GN1600',
#  'GN1100',
#  'GN0100',
#  'GN0800',
#  'GN1500',
#  'GN1600',
#  'GN0700',
#  'GN1200',
#  'GN2700',
#  'GN1200',
#  'GN1000',
#  'GN1700',
#  'GN2200',
#  'GN1600',
#  'GN1100',
#  'GN1400',
#  'GN1700',
#  'GN1800',
#  'GN0100',
#  'GN0200',
#  'GN2500 GN0200',
#  'GN1300',
#  'GN1200',
#  'GN0500 GN0100',
#  'GN0600',
#  'GN1000',
#  'GN1000',
#  'GN0400',
#  'GN1100',
#  'GN1800',
#  'GN0800',
#  'GN0900 GN1000',
#  'GN1800',
#  'GN1200',
#  'GN1800',
#  'GN1500',
#  'GN0800',
#  'GN1700',
#  'GN1200',
#  'GN1200 GN1300',
#  'GN0900',
#  'GN0900',
#  'GN1000',
#  'GN0900',
#  'GN1000',
#  'GN1700',
#  'GN1000',
#  'GN1600',
#  'GN1700',
#  'GN0100',
#  'GN1700',
#  'GN2100',
#  'GN0500 GN0800',
#  'GN0100',
#  'GN0900',
#  'GN0600',
#  'GN1100',
#  'GN0900',
#  'GN2200',
#  'GN1700',
#  'GN0300',
#  'GN1100',
#  'GN0900',
#  'GN1700',
#  'GN1200',
#  'GN1600',
#  'GN1100',
#  'GN1100',
#  'GN0600',
#  'GN1500',
#  'GN0800',
#  'GN1000',
#  'GN1000',
#  'GN1900',
#  'GN1800',
#  'GN1800',
#  'GN2000',
#  'GN1600',
#  'GN1800',
#  'GN1200',
#  'GN1600',
#  'GN0100',
#  'GN1800',
#  'GN1700',
#  'GN2200',
#  'GN1600',
#  'GN2000',
#  'GN0100',
#  'GN1200',
#  'GN2500 GN1500 GN0100',
#  'GN2700 GN1100',
#  'GN0500 GN0800',
#  'GN1800',
#  'GN0300',
#  'GN0900 GN1000',
#  'GN1700',
#  'GN1500',
#  'GN0500 GN0800',
#  'GN1700',
#  'GN0900',
#  'GN1100',
#  'GN0500 GN0800',
#  'GN0100',
#  'GN1500',
#  'GN0900',
#  'GN1400',
#  'GN0200',
#  'GN2200',
#  'GN1300',
#  'GN0700',
#  'GN2100',
#  'GN0700',
#  'GN0900',
#  'GN1400',
#  'GN1100',
#  'GN1400',
#  'GN1600',
#  'GN1000',
#  'GN0500 GN0300',
#  'GN1100',
#  'GN1100',
#  'GN1300',
#  'GN1700',
#  'GN1100',
#  'GN1800',
#  'GN1800',
#  'GN1600',
#  'GN1500',
#  'GN1700',
#  'GN1100',
#  'GN1500',
#  'GN1000',
#  'GN1500 GN0100',
#  'GN1400',
#  'GN1000',
#  'GN2700 GN1100',
#  'GN0900',
#  'GN2500 GN0200',
#  'GN1500 GN0800',
#  'GN1700',
#  'GN2500 GN0200',
#  'GN1500',
#  'GN1600',
#  'GN1100',
#  'GN2200',
#  'GN1800',
#  'GN1300',
#  'GN1000',
#  'GN0500 GN0300',
#  'GN1700',
#  'GN0500 GN0600',
#  'GN1700',
#  'GN1500 GN1900',
#  'GN1900',
#  'GN1200',
#  'GN0500 GN0600',
#  'GN1500 GN0100',
#  'GN1000',
#  'GN0600 GN0200',
#  'GN1800',
#  'GN1600',
#  'GN1700',
#  'GN1600',
#  'GN1600',
#  'GN1500 GN1300',
#  'GN0100',
#  'GN1500',
#  'GN1500 GN0100',
#  'GN0400',
#  'GN0600',
#  'GN1800',
#  'GN0700',
#  'GN0500 GN0300',
#  'GN0500 GN0800',
#  'GN0600',
#  'GN2000',
#  'GN0500 GN0800',
#  'GN2500 GN0200',
#  'GN1800',
#  'GN2100',
#  'GN1000',
#  'GN0100',
#  'GN2500 GN0600',
#  'GN1700',
#  'GN1400',
#  'GN0900',
#  'GN1900',
#  'GN2400',
#  'GN1200',
#  'GN1500',
#  'GN1000',
#  'GN1800',
#  'GN0500 GN0600',
#  'GN1900',
#  'GN2700 GN1100',
#  'GN1500',
#  'GN1700',
#  'GN1600',
#  'GN0600',
#  'GN0100',
#  'GN0500 GN0600',
#  'GN0900',
#  'GN1100',
#  'GN2600',
#  'GN1500',
#  'GN2200',
#  'GN1200',
#  'GN1800',
#  'GN1000',
#  'GN1700',
#  'GN1000',
#  'GN0300',
#  'GN0500 GN0300',
#  'GN1000',
#  'GN1200',
#  'GN1800',
#  'GN0900',
#  'GN1800',
#  'GN1900',
#  'GN0900',
#  'GN1600',
#  'GN0500 GN0100',
#  'GN1600',
#  'GN2200',
#  'GN0500 GN0800',
#  'GN1500',
#  'GN0900',
#  'GN1200',
#  'GN1200',
#  'GN0500 GN0300',
#  'GN0900',
#  'GN0900',
#  'GN1500',
#  'GN2700 GN1100',
#  'GN2700',
#  'GN1500',
#  'GN1000',
#  'GN1600',
#  'GN1100',
#  'GN0200',
#  'GN2600',
#  'GN1100',
#  'GN1200',
#  'GN0900',
#  'GN1000',
#  'GN0900',
#  'GN1300',
#  'GN1600',
#  'GN2000',
#  'GN1700',
#  'GN1700',
#  'GN1500',
#  'GN1500',
#  'GN0100',
#  'GN1200',
#  'GN1000',
#  'GN1200',
#  'GN0300',
#  'GN1300',
#  'GN2500 GN0100',
#  'GN1800',
#  'GN0900',
#  'GN1500',
#  'GN0100',
#  'GN1000',
#  'GN0100',
#  'GN1800',
#  'GN2000',
#  'GN1800',
#  'GN2200',
#  'GN0900',
#  'GN1000',
#  'GN1600',
#  'GN1100',
#  'GN0500 GN0600',
#  'GN1600',
#  'GN1900',
#  'GN0100',
#  'GN2000',
#  'GN0100',
#  'GN1800',
#  'GN1800',
#  'GN0900',
#  'GN0500 GN0800',
#  'GN1600',
#  'GN0900',
#  'GN2100',
#  'GN1300',
#  'GN0400',
#  'GN0500 GN0800',
#  'GN2200',
#  'GN0900',
#  'GN1600',
#  'GN1400',
#  'GN1100',
#  'GN1500',
#  'GN0700',
#  'GN1000',
#  '',
#  'GN1600',
#  'GN0900',
#  'GN2100',
#  'GN0100',
#  'GN1300',
#  'GN0100',
#  'GN1800',
#  'GN0800',
#  'GN1900',
#  'GN1100',
#  'GN1300',
#  'GN0100',
#  'GN1500 GN0200',
#  'GN1500',
#  'GN1700',
#  'GN1700',
#  'GN1800',
#  'GN1200',
#  'GN1600',
#  'GN0500 GN0800',
#  'GN1100',
#  'GN1700',
#  'GN1400',
#  'GN1100',
#  'GN1000',
#  'GN0500 GN0600',
#  'GN1100',
#  'GN1000',
#  'GN1900',
#  'GN1000',
#  'GN1200',
#  'GN1300',
#  'GN0900',
#  'GN2200',
#  'GN1300',
#  'GN2200',
#  'GN0900',
#  'GN0900',
#  'GN1100',
#  'GN1500',
#  'GN1600',
#  'GN0100',
#  'GN0900',
#  'GN1800',
#  'GN0700',
#  'GN1000',
#  'GN1600',
#  'GN1100',
#  'GN1700',
#  'GN0300',
#  'GN1000',
#  'GN1000',
#  'GN0900',
#  'GN2000',
#  'GN1100',
#  'GN2100',
#  'GN0400 GN2500',
#  'GN2500 GN0100',
#  'GN0400',
#  'GN0900 GN1000',
#  'GN0400',
#  'GN1800',
#  'GN1000',
#  'GN1400',
#  'GN0900',
#  'GN0600',
#  'GN0900',
#  'GN0100',
#  'GN0300',
#  'GN2100',
#  'GN2500 GN0100',
#  'GN0100',
#  'GN1800',
#  'GN0600 GN1500',
#  'GN1200',
#  'GN0500 GN0400',
#  'GN0600',
#  'GN1400',
#  'GN1700',
#  'GN1400',
#  'GN1500 GN0100',
#  'GN0100',
#  'GN0900 GN1000',
#  'GN1600',
#  'GN1200',
#  'GN2500 GN0600',
#  'GN1000',
#  'GN1200',
#  'GN0900',
#  'GN1900',
#  'GN1800',
#  'GN1900',
#  'GN0900 GN1000',
#  'GN1300',
#  'GN0500 GN2600',
#  'GN2200',
#  'GN1900',
#  'GN1200',
#  'GN1700',
#  'GN0900',
#  'GN1300',
#  'GN1300',
#  'GN1100',
#  'GN1300',
#  'GN1600',
#  'GN0900',
#  'GN0500 GN0800',
#  'GN1900',
#  'GN2700 GN1100',
#  'GN0700',
#  'GN2500 GN0300',
#  'GN1900',
#  'GN9000',
#  'GN1100',
#  'GN1900',
#  'GN0200',
#  'GN1300',
#  'GN1700',
#  'GN0100',
#  'GN0800',
#  'GN1300',
#  'GN1600',
#  'GN1100',
#  'GN0300',
#  'GN1200',
#  'GN1200',
#  'GN2500 GN0200',
#  'GN1500 GN0100',
#  'GN1700',
#  'GN0500 GN0100',
#  'GN1800',
#  'GN1800',
#  'GN2700 GN1100',
#  'GN1100',
#  'GN0900 GN1300',
#  'GN1600',
#  'GN1200',
#  'GN2000',
#  'GN1500',
#  'GN1000',
#  'GN1600',
#  'GN2500 GN0200',
#  'GN1000',
#  'GN0300',
#  'GN2100',
#  'GN0600',
#  'GN1800',
#  'GN2100',
#  'GN0900',
#  'GN0100',
#  'GN0800',
#  'GN1100',
#  'GN2700 GN1100',
#  'GN0900',
#  'GN0700',
#  'GN1300',
#  'GN2000',
#  'GN0900',
#  'GN1700',
#  'GN1100',
#  'GN0900',
#  'GN0900 GN1000',
#  'GN2600',
#  'GN1200',
#  'GN0500 GN0800',
#  'GN1200',
#  'GN0900',
#  'GN1200',
#  'GN0900',
#  'GN1500',
#  'GN1500',
#  'GN1800',
#  'GN1700',
#  'GN0300',
#  'GN2700 GN1100',
#  'GN0600',
#  'GN1600',
#  'GN0700',
#  'GN1500',
#  'GN1600',
#  'GN2600',
#  'GN0500 GN0300',
#  'GN1700',
#  'GN1600',
#  'GN2700 GN1100',
#  'GN0900',
#  'GN1900',
#  'GN1800',
#  'GN2200',
#  'GN0300',
#  'GN2700 GN1100',
#  'GN1000',
#  'GN1200',
#  'GN2100',
#  'GN1600',
#  'GN1700',
#  ...]

# %%
sub = pd.DataFrame(sub)
song['대분류str']=sub


song.head(10)
# Out:
#                 곡 세부 장르 리스트       발매일  ... 곡 ID  대분류str
# 0                  [GN0901]  20140512  ...    0  GN0900
# 1          [GN1601, GN1606]  20080421  ...    1  GN1600
# 2                  [GN0901]  20180518  ...    2  GN0900
# 3          [GN1102, GN1101]  20151016  ...    3  GN1100
# 4          [GN1802, GN1801]  20110824  ...    4  GN1800
# 5                  [GN1701]  20100602  ...    5  GN1700
# 6  [GN1601, GN1602, GN1614]  20170208  ...    6  GN1600
# 7  [GN1601, GN1602, GN1614]  20190315  ...    7  GN1600
# 8                  [GN0301]  20070625  ...    8  GN0300
# 9          [GN0105, GN0101]  20170320  ...    9  GN0100
#
# [10 rows x 10 columns]

# %%
song.tail()
# Out:
#              곡 세부 장르 리스트       발매일  ...    곡 ID    대분류str
# 707984          [GN2001]  19991219  ...  707984  [GN2000]
# 707985          [GN0901]  19860000  ...  707985  [GN0900]
# 707986  [GN0105, GN0101]  20160120  ...  707986  [GN0100]
# 707987  [GN1807, GN1801]  20131217  ...  707987  [GN1800]
# 707988  [GN0601, GN0604]  19980000  ...  707988  [GN0600]
#
# [5 rows x 10 columns]

# %% [markdown]
# ## genre_gn_all
# ##### 장르에 대한 정보

# %%
genre_gn_all = pd.read_json('/content/drive/Shareddrives/BOAZ_Adv/melon_data/genre_gn_all.json', orient = 'index')
genre_gn_all = pd.DataFrame(genre_gn_all) 
genre_gn_all.head()
# Out:
#              0
# GN0100     발라드
# GN0101  세부장르전체
# GN0102     '80
# GN0103     '90
# GN0104     '00

# %%
genre_gn_all.reset_index(inplace = True)
genre_gn_all.columns = ['장르 코드', '장르']
genre_gn_all
# Out:
#       장르 코드      장르
# 0    GN0100     발라드
# 1    GN0101  세부장르전체
# 2    GN0102     '80
# 3    GN0103     '90
# 4    GN0104     '00
# ..      ...     ...
# 249  GN2900     뮤지컬
# 250  GN2901  세부장르전체
# 251  GN2902   국내뮤지컬
# 252  GN2903   국외뮤지컬
# 253  GN3000   크리스마스
#
# [254 rows x 2 columns]

# %%
big_cat = genre_gn_all[genre_gn_all['장르 코드'].str[-2:] == '00']    #대분류만 뽑음
big_cat
# Out:
#       장르 코드          장르
# 0    GN0100         발라드
# 6    GN0200          댄스
# 12   GN0300        랩/힙합
# 18   GN0400    R&B/Soul
# 22   GN0500        인디음악
# 32   GN0600        록/메탈
# 39   GN0700        성인가요
# 50   GN0800      포크/블루스
# 56   GN0900         POP
# 65   GN1000        록/메탈
# 80   GN1100      일렉트로니카
# 90   GN1200        랩/힙합
# 100  GN1300    R&B/Soul
# 109  GN1400  포크/블루스/컨트리
# 117  GN1500         OST
# 128  GN1600         클래식
# 144  GN1700          재즈
# 155  GN1800        뉴에이지
# 163  GN1900       J-POP
# 176  GN2000        월드뮤직
# 187  GN2100         CCM
# 198  GN2200      어린이/태교
# 215  GN2300        종교음악
# 218  GN2400          국악
# 225  GN2500         아이돌
# 232  GN2600      일렉트로니카
# 237  GN2700         EDM
# 242  GN2800       뮤직테라피
# 249  GN2900         뮤지컬
# 253  GN3000       크리스마스

# %%
big_cat_gen = big_cat['장르 코드']     #대분류 코드만 뽑는다
big_cat_gen = big_cat_gen.reset_index(drop=True)

big_cat_gen
# Out:
# 0     GN0100
# 1     GN0200
# 2     GN0300
# 3     GN0400
# 4     GN0500
# 5     GN0600
# 6     GN0700
# 7     GN0800
# 8     GN0900
# 9     GN1000
# 10    GN1100
# 11    GN1200
# 12    GN1300
# 13    GN1400
# 14    GN1500
# 15    GN1600
# 16    GN1700
# 17    GN1800
# 18    GN1900
# 19    GN2000
# 20    GN2100
# 21    GN2200
# 22    GN2300
# 23    GN2400
# 24    GN2500
# 25    GN2600
# 26    GN2700
# 27    GN2800
# 28    GN2900
# 29    GN3000
# Name: 장르 코드, dtype: object

# %%
발라드 = song[song['대분류str'].str.contains(big_cat_gen[0])]    #발라드 한번 출력해봄
발라드.sample(100)
# Out:
#                                      곡 세부 장르 리스트  ...         대분류str
# 632928                                  [GN0101]  ...         GN0100
# 452358  [GN0509, GN0105, GN0101, GN0506, GN0501]  ...  GN0500 GN0100
# 376298                          [GN0105, GN0101]  ...         GN0100
# 32616   [GN0509, GN0105, GN0101, GN0506, GN0501]  ...  GN0500 GN0100
# 277160                          [GN0101, GN0103]  ...         GN0100
# ...                                          ...  ...            ...
# 228795  [GN0509, GN0105, GN0101, GN0506, GN0501]  ...  GN0500 GN0100
# 248628                          [GN0105, GN0101]  ...         GN0100
# 652843                          [GN0105, GN0101]  ...         GN0100
# 541493                          [GN0104, GN0101]  ...         GN0100
# 173059                          [GN0101, GN0103]  ...         GN0100
#
# [100 rows x 10 columns]

# %%
print(big_cat[big_cat['장르 코드']=='GN3000'])
print(big_cat_gen[29])
크리스마스 = song[song['대분류str'].str.contains(big_cat_gen[29])]    #크리스마스 장르 데이터 없음
크리스마스.sample(100)
# Out:
#       장르 코드     장르
# 253  GN3000  크리스마스
# GN3000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-53640ad3e866> in <module>()
#       2 print(big_cat_gen[29])
#       3 크리스마스 = song[song['대분류str'].str.contains(big_cat_gen[29])]    #크리스마스 장르 데이터 없음
# ----> 4 크리스마스.sample(100)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    4993             )
#    4994
# -> 4995         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    4996         return self.take(locs, axis=axis)
#    4997
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
ans = []
for i in big_cat_gen:
  if i == 'GN3000':
    break
  print(i)
  sub = song[song['대분류str'].str.contains(i)]
  sub = list(sub.sample(100).index)
  for i in sub:
    ans.append(i)
  
ans
# Out:
# GN0100
# GN0200
# GN0300
# GN0400
# GN0500
# GN0600
# GN0700
# GN0800
# GN0900
# GN1000
# GN1100
# GN1200
# GN1300
# GN1400
# GN1500
# GN1600
# GN1700
# GN1800
# GN1900
# GN2000
# GN2100
# GN2200
# GN2300
# GN2400
# GN2500
# GN2600
# GN2700
# GN2800
# GN2900
# [112762,
#  151918,
#  259924,
#  454017,
#  482940,
#  332267,
#  257873,
#  48488,
#  115371,
#  705817,
#  95928,
#  118557,
#  307583,
#  364869,
#  107060,
#  518032,
#  360809,
#  416355,
#  438434,
#  482402,
#  305055,
#  263361,
#  306854,
#  588174,
#  448654,
#  511007,
#  113557,
#  29774,
#  245338,
#  688117,
#  210168,
#  217665,
#  508851,
#  431435,
#  614335,
#  327730,
#  200367,
#  489773,
#  526240,
#  258500,
#  449445,
#  551447,
#  238828,
#  410245,
#  310817,
#  677154,
#  54994,
#  453270,
#  465266,
#  1840,
#  87103,
#  250084,
#  680234,
#  631914,
#  359126,
#  183326,
#  292274,
#  126745,
#  162113,
#  173171,
#  478568,
#  354298,
#  490468,
#  241793,
#  536880,
#  59155,
#  481382,
#  611373,
#  441414,
#  619461,
#  20701,
#  133049,
#  133261,
#  414009,
#  390992,
#  295064,
#  553699,
#  145728,
#  550271,
#  22688,
#  159532,
#  454695,
#  342733,
#  27758,
#  385843,
#  372050,
#  121909,
#  103670,
#  263563,
#  555410,
#  376229,
#  136167,
#  19027,
#  288096,
#  419460,
#  420455,
#  157959,
#  462551,
#  568246,
#  359888,
#  656524,
#  569762,
#  603856,
#  705593,
#  153633,
#  457628,
#  461427,
#  197627,
#  44733,
#  313307,
#  422029,
#  498916,
#  102375,
#  527623,
#  261338,
#  98501,
#  408824,
#  192569,
#  415623,
#  598327,
#  659511,
#  389089,
#  486209,
#  204821,
#  591813,
#  122774,
#  248856,
#  488424,
#  235806,
#  158108,
#  616067,
#  158237,
#  433057,
#  227118,
#  213977,
#  334017,
#  633567,
#  458060,
#  321610,
#  33992,
#  744,
#  65236,
#  379146,
#  382413,
#  287571,
#  244656,
#  518505,
#  133881,
#  70218,
#  290516,
#  600166,
#  269080,
#  320614,
#  117681,
#  679956,
#  690715,
#  128239,
#  604962,
#  243182,
#  220746,
#  603812,
#  556909,
#  313397,
#  637476,
#  693735,
#  124291,
#  299932,
#  113664,
#  542463,
#  522524,
#  276950,
#  222176,
#  210454,
#  637154,
#  487597,
#  660049,
#  109637,
#  589570,
#  135445,
#  652246,
#  690285,
#  43071,
#  7027,
#  577281,
#  117527,
#  337507,
#  294229,
#  624935,
#  27310,
#  469619,
#  682394,
#  682254,
#  341722,
#  612556,
#  255546,
#  129484,
#  224649,
#  256083,
#  87631,
#  638088,
#  331724,
#  594500,
#  415701,
#  662305,
#  488339,
#  555981,
#  676886,
#  304597,
#  110287,
#  323719,
#  210005,
#  78520,
#  218240,
#  187983,
#  372630,
#  118996,
#  266998,
#  129205,
#  567449,
#  157040,
#  133149,
#  16666,
#  212438,
#  357358,
#  286069,
#  248343,
#  648116,
#  267934,
#  409105,
#  352970,
#  512329,
#  555761,
#  165659,
#  325236,
#  400586,
#  98192,
#  383795,
#  524537,
#  603956,
#  683225,
#  226111,
#  707077,
#  345293,
#  702226,
#  597258,
#  476527,
#  358549,
#  400042,
#  488239,
#  30419,
#  56144,
#  563679,
#  614105,
#  634323,
#  631155,
#  590329,
#  635759,
#  66849,
#  536668,
#  662551,
#  338778,
#  664314,
#  223353,
#  627171,
#  572308,
#  168491,
#  352440,
#  422397,
#  295537,
#  314251,
#  156997,
#  437172,
#  472584,
#  228077,
#  467736,
#  595461,
#  471983,
#  628518,
#  587702,
#  492343,
#  568982,
#  261158,
#  370044,
#  331194,
#  620314,
#  82296,
#  663463,
#  149708,
#  631803,
#  478197,
#  127018,
#  133000,
#  56543,
#  191862,
#  36659,
#  43310,
#  638538,
#  304873,
#  587414,
#  157854,
#  547255,
#  702822,
#  357440,
#  522102,
#  211519,
#  216213,
#  583805,
#  128000,
#  666909,
#  674549,
#  67040,
#  172020,
#  234243,
#  540128,
#  572686,
#  554278,
#  118029,
#  147199,
#  301028,
#  687119,
#  626369,
#  516444,
#  316121,
#  362986,
#  214000,
#  196878,
#  479729,
#  642089,
#  424107,
#  16693,
#  678539,
#  608686,
#  19504,
#  554524,
#  281385,
#  232810,
#  341505,
#  339812,
#  431834,
#  492555,
#  108614,
#  569703,
#  560792,
#  604694,
#  196285,
#  482444,
#  191533,
#  223776,
#  204978,
#  47876,
#  513632,
#  74046,
#  474015,
#  179785,
#  542680,
#  357367,
#  673280,
#  342063,
#  400437,
#  127443,
#  425542,
#  392541,
#  473728,
#  206090,
#  594571,
#  658056,
#  293132,
#  445222,
#  384485,
#  96729,
#  295240,
#  526774,
#  314631,
#  181888,
#  520518,
#  517909,
#  541936,
#  320851,
#  136342,
#  394712,
#  455388,
#  60578,
#  95721,
#  532836,
#  166457,
#  86240,
#  90269,
#  257778,
#  360589,
#  215593,
#  87008,
#  572163,
#  627972,
#  582322,
#  669828,
#  63006,
#  485658,
#  109446,
#  342297,
#  325957,
#  347159,
#  635672,
#  313128,
#  706567,
#  17893,
#  170299,
#  167251,
#  538003,
#  499063,
#  676726,
#  195529,
#  425440,
#  158596,
#  87731,
#  438663,
#  170117,
#  575651,
#  185404,
#  89958,
#  552379,
#  266228,
#  425443,
#  538260,
#  95383,
#  114929,
#  688898,
#  654551,
#  63877,
#  479536,
#  121384,
#  178580,
#  227350,
#  459852,
#  490758,
#  426643,
#  484944,
#  608831,
#  419070,
#  295653,
#  8912,
#  234921,
#  383586,
#  206703,
#  191117,
#  243903,
#  370218,
#  418528,
#  51827,
#  557849,
#  15746,
#  73674,
#  485787,
#  195701,
#  301999,
#  697233,
#  52634,
#  346846,
#  665759,
#  407691,
#  620069,
#  470881,
#  364867,
#  130640,
#  571363,
#  256626,
#  91243,
#  241698,
#  157626,
#  36701,
#  132912,
#  349027,
#  329704,
#  294920,
#  501003,
#  627604,
#  649408,
#  486457,
#  138543,
#  63620,
#  475684,
#  512651,
#  251307,
#  51663,
#  593714,
#  16397,
#  170096,
#  11713,
#  639133,
#  584767,
#  108550,
#  527046,
#  152296,
#  573432,
#  151214,
#  372188,
#  482003,
#  110441,
#  207268,
#  487896,
#  559117,
#  625746,
#  625309,
#  428412,
#  167682,
#  561720,
#  244600,
#  508089,
#  289281,
#  174816,
#  632770,
#  492103,
#  314046,
#  433070,
#  151387,
#  526046,
#  58469,
#  191116,
#  538360,
#  435236,
#  418747,
#  465975,
#  557735,
#  600076,
#  324689,
#  8093,
#  66936,
#  205170,
#  671837,
#  335736,
#  566039,
#  468262,
#  301296,
#  545472,
#  23327,
#  341073,
#  363194,
#  624277,
#  439490,
#  12296,
#  678982,
#  180003,
#  662289,
#  24462,
#  392415,
#  699291,
#  109424,
#  642619,
#  294904,
#  7757,
#  657152,
#  151726,
#  352383,
#  534571,
#  538586,
#  437032,
#  422761,
#  80059,
#  387190,
#  330425,
#  412658,
#  351169,
#  473041,
#  104195,
#  504579,
#  176491,
#  329635,
#  441054,
#  59704,
#  656817,
#  449720,
#  91149,
#  16443,
#  678355,
#  212926,
#  228024,
#  307306,
#  506791,
#  19179,
#  212763,
#  530232,
#  355016,
#  700102,
#  499373,
#  65900,
#  207393,
#  8213,
#  547565,
#  178420,
#  465937,
#  7067,
#  213737,
#  694700,
#  607236,
#  705762,
#  69873,
#  639562,
#  488263,
#  141835,
#  356992,
#  519215,
#  62454,
#  111642,
#  597554,
#  593782,
#  680088,
#  30173,
#  586978,
#  348270,
#  191575,
#  46467,
#  34474,
#  154680,
#  533346,
#  621659,
#  8682,
#  358509,
#  628414,
#  421934,
#  31880,
#  570043,
#  298340,
#  363160,
#  394860,
#  181043,
#  179472,
#  511962,
#  58432,
#  190490,
#  441327,
#  162301,
#  79133,
#  558679,
#  344397,
#  356685,
#  273735,
#  394611,
#  316189,
#  464778,
#  330630,
#  336614,
#  704050,
#  18894,
#  253830,
#  589244,
#  691732,
#  673983,
#  386598,
#  23700,
#  124477,
#  240749,
#  89800,
#  696434,
#  235630,
#  264620,
#  324038,
#  45886,
#  52989,
#  504587,
#  191742,
#  101219,
#  331145,
#  44588,
#  297881,
#  671472,
#  371599,
#  158880,
#  161568,
#  15072,
#  475708,
#  270142,
#  400604,
#  228631,
#  155378,
#  526314,
#  694743,
#  480765,
#  595329,
#  86890,
#  335032,
#  400451,
#  646943,
#  342538,
#  477383,
#  472075,
#  78678,
#  85329,
#  519617,
#  226067,
#  345263,
#  522864,
#  515628,
#  596497,
#  143642,
#  237891,
#  307502,
#  275093,
#  586493,
#  615184,
#  656040,
#  525653,
#  88203,
#  557531,
#  663383,
#  95462,
#  300832,
#  238495,
#  288982,
#  571630,
#  558921,
#  42042,
#  704705,
#  495396,
#  422171,
#  325554,
#  633102,
#  153233,
#  120908,
#  237974,
#  620215,
#  631142,
#  30338,
#  365353,
#  143089,
#  291350,
#  83615,
#  24869,
#  513394,
#  284984,
#  362268,
#  653017,
#  131216,
#  528183,
#  183531,
#  310911,
#  123887,
#  463097,
#  351948,
#  368090,
#  286963,
#  186094,
#  670380,
#  551767,
#  119514,
#  365372,
#  352256,
#  279091,
#  369328,
#  315573,
#  546295,
#  531527,
#  254842,
#  286566,
#  463310,
#  395148,
#  624108,
#  567713,
#  620181,
#  109199,
#  230611,
#  703678,
#  657623,
#  95364,
#  315327,
#  654462,
#  119417,
#  468130,
#  540208,
#  597657,
#  263538,
#  274376,
#  280257,
#  688074,
#  298201,
#  199064,
#  49551,
#  249897,
#  236877,
#  255403,
#  232896,
#  511465,
#  68513,
#  292165,
#  622100,
#  629798,
#  614875,
#  181781,
#  695369,
#  154202,
#  674232,
#  6644,
#  406731,
#  331812,
#  370090,
#  464428,
#  549511,
#  371653,
#  225440,
#  350917,
#  492253,
#  478124,
#  9251,
#  64785,
#  266521,
#  153998,
#  183378,
#  617934,
#  54463,
#  510084,
#  369398,
#  612373,
#  561407,
#  676083,
#  22629,
#  608362,
#  560758,
#  4003,
#  141649,
#  441542,
#  306189,
#  461152,
#  310474,
#  184977,
#  323797,
#  186734,
#  180717,
#  445628,
#  574101,
#  458102,
#  479744,
#  541896,
#  259218,
#  552915,
#  674394,
#  522171,
#  72315,
#  250090,
#  512863,
#  21048,
#  547135,
#  632765,
#  233001,
#  126763,
#  102233,
#  517828,
#  198449,
#  365613,
#  16486,
#  431880,
#  323648,
#  590779,
#  427438,
#  160867,
#  347257,
#  235840,
#  98827,
#  605524,
#  213251,
#  199119,
#  651388,
#  244440,
#  6427,
#  378459,
#  513360,
#  449605,
#  49334,
#  137395,
#  248906,
#  594645,
#  232772,
#  460841,
#  267876,
#  175424,
#  680066,
#  506464,
#  382587,
#  655129,
#  629937,
#  189291,
#  461660,
#  69605,
#  190391,
#  399040,
#  511789,
#  310933,
#  534977,
#  562818,
#  244626,
#  59665,
#  582613,
#  283496,
#  653121,
#  472516,
#  65376,
#  380230,
#  462762,
#  270206,
#  109284,
#  582928,
#  468479,
#  530978,
#  438954,
#  501815,
#  210844,
#  647623,
#  299561,
#  470301,
#  625716,
#  565464,
#  141209,
#  524066,
#  545971,
#  106375,
#  271933,
#  82547,
#  292960,
#  381148,
#  389317,
#  330760,
#  298587,
#  484270,
#  472823,
#  31512,
#  197890,
#  706067,
#  440716,
#  339566,
#  182034,
#  646257,
#  371270,
#  216638,
#  616745,
#  655894,
#  228955,
#  267242,
#  353205,
#  114717,
#  444359,
#  113928,
#  59575,
#  414289,
#  406795,
#  301421,
#  85793,
#  588510,
#  167721,
#  289894,
#  31998,
#  541889,
#  588303,
#  56051,
#  637551,
#  425428,
#  6430,
#  653446,
#  299911,
#  441882,
#  182499,
#  416427,
#  668458,
#  334709,
#  691501,
#  428328,
#  401442,
#  566210,
#  391101,
#  414161,
#  584291,
#  700750,
#  281262,
#  595105,
#  492068,
#  226116,
#  222513,
#  579860,
#  321676,
#  520129,
#  372762,
#  256605,
#  9958,
#  21193,
#  623052,
#  276713,
#  132726,
#  686113,
#  87350,
#  612915,
#  570714,
#  319376,
#  275208,
#  446727,
#  75510,
#  518231,
#  19972,
#  26721,
#  696152,
#  21848,
#  609168,
#  554099,
#  703849,
#  116838,
#  ...]

# %%
len(ans)
# Out:
# 2900

# %%
sample_song = song.iloc[ans]
sample_song.to_csv('/content/drive/MyDrive/adv/sampling_song_data.csv',index =False)

# %%
pd.read_csv('/content/drive/MyDrive/adv/sampling_song_data.csv')
# Out:
#                                    곡 세부 장르 리스트       발매일  ...    곡 ID         대분류str
# 0                                   ['GN0101']  20130315  ...  112762         GN0100
# 1                                   ['GN0101']  20120722  ...  151918         GN0100
# 2                                   ['GN0101']  20030312  ...  259924         GN0100
# 3                         ['GN0104', 'GN0101']  20090915  ...  454017         GN0100
# 4                                   ['GN0101']  20080610  ...  482940         GN0100
# ...                                        ...       ...  ...     ...            ...
# 2895  ['GN1501', 'GN1508', 'GN2903', 'GN2901']  20120306  ...  706190  GN1500 GN2900
# 2896  ['GN1501', 'GN1508', 'GN2903', 'GN2901']  20131212  ...   59356  GN1500 GN2900
# 2897  ['GN1507', 'GN1501', 'GN2902', 'GN2901']  20090421  ...  126634  GN1500 GN2900
# 2898  ['GN1501', 'GN1508', 'GN2903', 'GN2901']  20151230  ...  145365  GN1500 GN2900
# 2899  ['GN2902', 'GN1501', 'GN1507', 'GN2901']  20190402  ...  470883  GN1500 GN2900
#
# [2900 rows x 10 columns]
